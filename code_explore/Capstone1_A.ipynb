# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
death_2014 = pd.read_csv('/home/allen/Galva/capstones/capstone1/Weekly_Counts_of_Deaths_by_State_and_Select_Causes__2014-2018.csv')
death_2019 = pd.read_csv('/home/allen/Galva/capstones/capstone1/Weekly_Counts_of_Deaths_by_State_and_Select_Causes__2019-2020.csv')
death_master = pd.concat([death_2014 , death_2019])

# %%
death_columns = death_master.columns 
death_cols_to_remove = ['Jurisdiction of Occurrence','Malignant neoplasms (C00-C97)', 'Septicemia (A40-A41)','Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)']
for i in death_columns:
    if i[0] == 'f':
        death_cols_to_remove.append(i)
    if "COVID" in i:
        death_cols_to_remove.append(i)

death_master.drop(death_cols_to_remove, axis =1 , inplace=True)

# %%
death_master.columns
# Out:
# Index(['MMWR Year', 'MMWR Week', 'Week Ending Date', 'All  Cause',
#        'Natural Cause', 'Diabetes mellitus (E10-E14)',
#        'Alzheimer disease (G30)', 'Influenza and pneumonia (J10-J18)',
#        'Chronic lower respiratory diseases (J40-J47)',
#        'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)',
#        'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
#        'Diseases of heart (I00-I09,I11,I13,I20-I51)',
#        'Cerebrovascular diseases (I60-I69)', 'All Cause',
#        'Influenza and pneumonia (J09-J18)'],
#       dtype='object')

# %%
death_master.columns =

# %%
pm10_2014 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm10_2014.csv')
pm10_2015 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm10_2015.csv')
pm10_2016 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm10_2016.csv')
pm10_2017 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm10_2017.csv')
pm10_2018 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm10_2018.csv')
pm10_2019 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm10_2019.csv')

pm10_master = pd.concat([pm10_2014, pm10_2015,pm10_2016,pm10_2017,pm10_2018,pm10_2019])

pm10_master.shape
# Out:
# (8061, 20)

# %%
pm10_master['POC'].describe()
# Out:
# count    8061.000000
# mean        1.666046
# std         0.871737
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max         3.000000
# Name: POC, dtype: float64

# %%
pm25u = pm25_master['Site ID'].unique()
print(pm25u)
# Out:
# [80010006 80050005 80310002 80310026 80310027 80350004 80350005 80310028
#  80930002 80010008 80310013]

# %%
num_id = [80010006 ,80050005 ,80310002, 80310026 ,80310027, 80350004 ,80350005 ,80310028,80930002 ,80010008 ,80310013]
for i in num_id:
    print(pm25_master[pm25_master['Site ID'] == i].count(), f'for this site id{i}')
# Out:
# Date                              290
# Source                            290
# Site ID                           290
# POC                               290
# Daily Mean PM2.5 Concentration    290
# UNITS                             290
# DAILY_AQI_VALUE                   290
# Site Name                         290
# DAILY_OBS_COUNT                   290
# PERCENT_COMPLETE                  290
# AQS_PARAMETER_CODE                290
# AQS_PARAMETER_DESC                290
# CBSA_CODE                         290
# CBSA_NAME                         290
# STATE_CODE                        290
# STATE                             290
# COUNTY_CODE                       290
# COUNTY                            290
# SITE_LATITUDE                     290
# SITE_LONGITUDE                    290
# dtype: int64 for this site id80010006
# Date                              721
# Source                            721
# Site ID                           721
# POC                               721
# ...

# %%
num_id = [80010006 ,80050005 ,80310002, 80310026 ,80310027, 80350004 ,80350005 ,80310028,80930002 ,80010008 ,80310013]
dict_p10={}
for i in num_id:
    print(pm10_master[pm10_master['Site ID'] == i].count(), f'for this site id{i}')
# Out:
# Date                             480
# Source                           480
# Site ID                          480
# POC                              480
# Daily Mean PM10 Concentration    480
# UNITS                            480
# DAILY_AQI_VALUE                  480
# Site Name                        480
# DAILY_OBS_COUNT                  480
# PERCENT_COMPLETE                 480
# AQS_PARAMETER_CODE               480
# AQS_PARAMETER_DESC               480
# CBSA_CODE                        480
# CBSA_NAME                        480
# STATE_CODE                       480
# STATE                            480
# COUNTY_CODE                      480
# COUNTY                           480
# SITE_LATITUDE                    480
# SITE_LONGITUDE                   480
# dtype: int64 for this site id80010006
# Date                             0
# Source                           0
# Site ID                          0
# POC                              0
# ...

# %% [markdown]
# The above result shows 80310002 has the most measures

# %%
290, 80010006

# %%
pm25_site1 = pm25_master[pm25_master['Site ID'] == 80310026]
pm10_site1 = pm10_master[pm10_master['Site ID'] == 80310026]

# %%
pm25_site1.shape
# Out:
# (2488, 20)

# %%
pm25_2014 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm_25_2014.csv')
pm25_2015 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm_25_2015.csv')
pm25_2016 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm_25_2016.csv')
pm25_2017 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm_25_2017.csv')
pm25_2018 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm_25_2018.csv')
pm25_2019 = pd.read_csv('/home/allen/Galva/capstones/capstone1/pm_25_2019.csv')

pm25_master = pd.concat([pm25_2014,pm25_2015,pm25_2016,pm25_2017,pm25_2018,pm25_2019])

pm25_master.shape
# Out:
# (17055, 20)

# %%
num_id_25 = [80010006 ,80050005 ,80310002, 80310027, 80350004 ,80350005 ,80310028,80930002 ,80010008 ,80310013]

# %%
def make_sites25(x):
    
    v=''
    pm25_sites = []
    lst=[]
    
    for index,value in enumerate(x):
        v += str(value)
        lst.append(v)
        v=''
        
    zipping = [(i,ii) for i,ii in list(zip(x,lst))]
    
    for i in zipping:
        
        v = pm25_master[pm25_master['Site ID'] == x[i]]
        pm25_sites.append(v)
        v = ''
        
    return pm25_sites

check = make_sites25(num_id_25)
print(check[0])

# %% [markdown]
# PM25 = 17055
# pm10 =  8061
# Total = 25116
# Missing = 1939 *

# %% [markdown]
# ''' Seems like I can take the higest reading and have a single POC value for each date'''
# '''To execute the above I would group by site ID and Date.

# %%
17055 + 8061 - 23177
# Out:
# 1939

# %%
pm10_dates = pm10_master['Date'].values 
pm10_date = []
for i in pm10_dates:
    i=str(i)
    i_=i.split("/")

    pm10_date.append(''.join(i_))

# %%
print(pm10_date[:10])
# Out:
# ['01012014', '01022014', '01032014', '01042014', '01052014', '01062014', '01072014', '01082014', '01092014', '01102014']

# %%
pm10_master['Date'] = pd.DatetimeIndex(pm10_master['Date']).date

# %%
pm25_master['Date'] = pd.DatetimeIndex(pm25_master['Date']).date

# %%
# Out:
# count           8061
# unique          2187
# top       2014-11-07
# freq               9
# Name: Date, dtype: object

# %%
pm10_master.shape
# Out:
# (8061, 20)

# %%
pm25_master.shape
# Out:
# (17055, 20)

# %%
pm2014m = pd.merge(pm25_master,pm10_master, how='outer', on = ['Site ID', 'Date', 'POC'])

# %%
pm_master = pd.concat([pm10_master,pm25_master])
#pm_master.info()

# %%
pm_master_cols = pm_master.columns
#pm_master1=pm_master.drop(['Source','AQS_PARAMETER_CODE','COUNTY','COUNTY_CODE', 'CBSA_CODE', 'CBSA_NAME', 'STATE','STATE_CODE', 'DAILY_OBS_COUNT', 'PERCENT_COMPLETE' ], axis=1, inplace=True )
pm_master[(pm_master['Date'] == '12/26/2015') & (pm_master['Site ID'] == 80310002)]
# Out:
#            Date Source   Site ID  POC  Daily Mean PM10 Concentration  \
# 562  12/26/2015    AQS  80310002    1                            8.0
# 621  12/26/2015    AQS  80310002    2                            9.0
# 531  12/26/2015    AQS  80310002    1                            NaN
# 599  12/26/2015    AQS  80310002    2                            NaN
# 959  12/26/2015    AQS  80310002    3                            NaN
#
#         UNITS  DAILY_AQI_VALUE      Site Name  DAILY_OBS_COUNT  \
# 562  ug/m3 SC                7  DENVER - CAMP                1
# 621  ug/m3 SC                8  DENVER - CAMP                1
# 531  ug/m3 LC               20  DENVER - CAMP                1
# 599  ug/m3 LC               21  DENVER - CAMP                1
# 959  ug/m3 LC               21  DENVER - CAMP                1
#
#      PERCENT_COMPLETE  ...        AQS_PARAMETER_DESC CBSA_CODE  \
# 562             100.0  ...     PM10 Total 0-10um STP     19740
# ...

# %%
pm25_site1.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %%
pm25_site1a = pm25_master[pm25_master['Site ID'] == 80310026]
pm10_site1a = pm10_master[pm10_master['Site ID'] == 80310026]

# %%
cols_2_drop = ['DAILY_OBS_COUNT','Source' , 'Site Name','PERCENT_COMPLETE' ,'AQS_PARAMETER_DESC','CBSA_CODE', 'STATE_CODE', 'STATE', 'COUNTY_CODE','COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'  ]

# %%
# pm25_site1.drop(cols_2_drop, axis =1 , inplace=True)
# pm10_site1.drop(cols_2_drop, axis =1 , inplace=True)

# %%
pm25_site1a.drop(cols_2_drop, axis =1 , inplace=True)
pm10_site1a.drop(cols_2_drop, axis =1 , inplace=True)
# Out:
# /home/allen/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
pm10_site1a.tail(5)
# Out:
#             Date   Site ID  POC  Daily Mean PM10 Concentration     UNITS  \
# 1030  2019-12-05  80310026    2                             16  ug/m3 SC
# 1031  2019-12-11  80310026    2                             42  ug/m3 SC
# 1032  2019-12-17  80310026    2                             29  ug/m3 SC
# 1033  2019-12-23  80310026    2                             39  ug/m3 SC
# 1034  2019-12-29  80310026    2                              8  ug/m3 SC
#
#       DAILY_AQI_VALUE  AQS_PARAMETER_CODE                   CBSA_NAME  \
# 1030               15               81102  Denver-Aurora-Lakewood, CO
# 1031               39               81102  Denver-Aurora-Lakewood, CO
# 1032               27               81102  Denver-Aurora-Lakewood, CO
# 1033               36               81102  Denver-Aurora-Lakewood, CO
# 1034                7               81102  Denver-Aurora-Lakewood, CO
#
#           Date_
# 1030 2019-12-05
# 1031 2019-12-11
# 1032 2019-12-17
# 1033 2019-12-23
# 1034 2019-12-29

# %%
#aggregrate weekly data from daily PMs#
df.groupby('Name').resample('W-Mon', on='Date').sum()

# %%
#pm10_master[(pm10_master['Date'] == '06/04/2018') ]

# %%
#pm10_master[(pm10_master['Date'] == '06/04/2018') & (pm10_master['Site ID'] == 80010008) ]

# %%
#pm_master[(pm_master['Date'] == '06/04/2018') & (pm_master['Site ID'] == 80010008) ]

# %% [markdown]
# --Could create a class function thing to automate combining data
# * get same dates
# **

# %%
66.95 chronic_lower
18.99 other
174.10999999999999 heart

# %%
sd2_weeks_heart = death_master[death_master['Diseases of heart (I00-I09,I11,I13,I20-I51)'] >= 174.1]

# %%
sd2_weeks_lowerRes = death_master[death_master['Chronic lower respiratory diseases (J40-J47)'] >= 66.95 ]

# %%
sd2_weeks_OtherRes = death_master[death_master['Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)'] >= 19.0]

# %%
heart_week = sd2_weeks_heart['Week Ending Date'].values
lower_week = sd2_weeks_lowerRes['Week Ending Date'].values
other_week = sd2_weeks_OtherRes['Week Ending Date'].values

# %%
death_master.head(1)
# Out:
#   Jurisdiction of Occurrence  MMWR Year  MMWR Week Week Ending Date  \
# 0                   Colorado       2014          1       01/04/2014
#
#    All  Cause  Natural Cause  Diabetes mellitus (E10-E14)  \
# 0       416.0            373                         12.0
#
#    Alzheimer disease (G30)  Influenza and pneumonia (J10-J18)  \
# 0                      NaN                               14.0
#
#    Chronic lower respiratory diseases (J40-J47)  \
# 0                                            33
#
#    Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)  \
# 0                                                NaN
#
#    Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)  \
# 0                                                NaN
#
#    Diseases of heart (I00-I09,I11,I13,I20-I51)  \
# 0                                           96
#
#    Cerebrovascular diseases (I60-I69)  All Cause  \
# 0                                  22        NaN
#
# ...

# %%
death_master.describe()
# Out:
#          MMWR Year   MMWR Week  All  Cause  Natural Cause  \
# count   354.000000  354.000000  261.000000     354.000000
# mean   2016.898305   25.937853  722.505747     655.971751
# std       1.964515   14.850400   58.451599      69.700446
# min    2014.000000    1.000000  416.000000     373.000000
# 25%    2015.000000   13.000000  686.000000     607.250000
# 50%    2017.000000   26.000000  718.000000     649.000000
# 75%    2019.000000   38.000000  757.000000     698.000000
# max    2020.000000   53.000000  947.000000    1002.000000
#
#        Diabetes mellitus (E10-E14)  Alzheimer disease (G30)  \
# count                   345.000000               353.000000
# mean                     18.942029                33.614731
# std                       4.561225                 8.182507
# min                      10.000000                11.000000
# 25%                      15.000000                28.000000
# 50%                      19.000000                34.000000
# ...

# %%
print(48.9 + (1.9 * 9.5) , 'chronic_lower')
print(13.1 + (1.9 * 3.1) , 'other') 
print(142 + (1.9 * 16.9) , 'heart')
# Out:
# 66.95 chronic_lower
# 18.99 other
# 174.10999999999999 heart

# %%
sig_pm25_dates = pm25_site1a[pm25_site1a['Daily Mean PM2.5 Concentration'] >= 16.1 ]

# %%
pm25_site1a.describe()
# Out:
#           Site ID          POC  Daily Mean PM2.5 Concentration  \
# count      2488.0  2488.000000                     2488.000000
# mean   80310026.0     2.480707                        7.263465
# std           0.0     1.005228                        4.731953
# min    80310026.0     1.000000                        0.900000
# 25%    80310026.0     1.000000                        4.500000
# 50%    80310026.0     3.000000                        6.200000
# 75%    80310026.0     3.000000                        8.500000
# max    80310026.0     5.000000                       58.600000
#
#        DAILY_AQI_VALUE  AQS_PARAMETER_CODE
# count      2488.000000         2488.000000
# mean         29.128215        88113.088023
# std          15.517453           68.578911
# min           4.000000        88101.000000
# 25%          19.000000        88101.000000
# 50%          26.000000        88101.000000
# 75%          35.000000        88101.000000
# max         153.000000        88502.000000

# %%
sig_pm25_dates['Date'].values
# Out:
# array(['2014-01-08T00:00:00.000000000', '2014-02-04T00:00:00.000000000',
#        '2014-02-07T00:00:00.000000000', '2014-02-10T00:00:00.000000000',
#        '2014-11-01T00:00:00.000000000', '2014-11-15T00:00:00.000000000',
#        '2014-12-01T00:00:00.000000000', '2014-12-04T00:00:00.000000000',
#        '2014-12-13T00:00:00.000000000', '2014-12-28T00:00:00.000000000',
#        '2014-12-31T00:00:00.000000000', '2014-01-08T00:00:00.000000000',
#        '2014-02-04T00:00:00.000000000', '2014-02-10T00:00:00.000000000',
#        '2014-06-01T00:00:00.000000000', '2014-07-04T00:00:00.000000000',
#        '2015-02-23T00:00:00.000000000', '2015-03-01T00:00:00.000000000',
#        '2015-07-08T00:00:00.000000000', '2015-08-22T00:00:00.000000000',
#        '2015-11-29T00:00:00.000000000', '2015-12-29T00:00:00.000000000',
#        '2015-03-01T00:00:00.000000000', '2015-03-02T00:00:00.000000000',
#        '2015-07-06T00:00:00.000000000', '2015-07-09T00:00:00.000000000',
# ...

# %%
# pd.to_datetime(pm25_sitela['Date'])
pm25_site1a['Date'] = pd.to_datetime(pm25_site1a['Date'])
# Out:
# <ipython-input-183-4b3b98535e4f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm25_site1a['Date'] = pd.to_datetime(pm25_site1a['Date'])

# %%
#aggregrate weekly data from daily PMs#
df_var = pm25_site1a.set_index('Date').resample('W-Sun').mean()

# %%
sd2_weeks = df_var[df_var['Daily Mean PM2.5 Concentration'] >= 16]
sd2_weeks.head(2)
# Out:
#                Site ID       POC  Daily Mean PM2.5 Concentration  \
# Date
# 2014-02-09  80310026.0  2.333333                       26.833333
# 2014-02-16  80310026.0  3.000000                       16.883333
#
#             DAILY_AQI_VALUE  AQS_PARAMETER_CODE
# Date
# 2014-02-09        82.333333        88234.666667
# 2014-02-16        51.000000        88301.500000

# %%
sd22 = sd2_weeks.index

# %%
hh = [i for i in sd22] #[ 2014-02-09 ,2014-02-16,2015-01-04 ,2015-03-01,2015-07-12 ,2015-08-23 ,2016-01-03 ,2016-01-10 ,2018-08-26 ,2019-02-10 ,2019-03-10 ,]
for i in hh:
    print(i)
# Out:
# 2014-02-09 00:00:00
# 2014-02-16 00:00:00
# 2015-01-04 00:00:00
# 2015-03-01 00:00:00
# 2015-07-12 00:00:00
# 2015-08-23 00:00:00
# 2016-01-03 00:00:00
# 2016-01-10 00:00:00
# 2018-08-26 00:00:00
# 2019-02-10 00:00:00
# 2019-03-10 00:00:00

# %%
h1 = [i for i in heart_week  ] # [01/03/2015,03/26/2016,01/13/2018,03/24/2018,2019-01-05,2019-01-12,2019-01-19,2019-02-16,2019-03-09,2019-03-23,2019-06-08]
h2 = [i for i in lower_week ] #[ 12/27/2014,01/03/2015,02/20/2016,03/26/2016,04/02/2016,01/14/2017,02/25/2017,12/30/2017,01/06/2018,01/13/2018,02/10/2018,02/17/2018,04/07/2018,2019-03-16,2019-04-13,]
h3 = [i for i in other_week] #[03/19/2016,01/14/2017,03/11/2017,01/06/2018,02/17/2018,03/31/2018,06/23/2018,2019-03-02,2019-09-21,2019-11-02]
for i in h3:
    print(i)
# Out:
# 03/19/2016
# 01/14/2017
# 03/11/2017
# 01/06/2018
# 02/17/2018
# 03/31/2018
# 06/23/2018
# 2019-03-02
# 2019-09-21
# 2019-11-02
# 2020-01-04
# 2020-01-25
# 2020-04-11

# %%
sns.distplot(death_master['Diseases of heart (I00-I09,I11,I13,I20-I51)'])

# %%
columns = death_master.columns

x_data = 360

fig, ax = plt.subplots()

for column in columns[2:]:
    ax.plot( death_master[column], label = column)
ax.legend();
plt.tight_layout()
plt.figure(figsize=(12,10))
